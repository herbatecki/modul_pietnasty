# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.2'

# %%
pd.read_csv('/home/kacki/Desktop/chat/currency_list.csv') # przykład odczytania pliku .csv
# Out:
#                    currency;code;bid;ask
# 0    dolar amerykański;USD;3.7702;3.8464
# 1    dolar australijski;AUD;2.7876;2.844
# 2                 euro;EUR;4.4699;4.5603
# 3   forint (Węgry);HUF;0.012824;0.013084
# 4    frank szwajcarski;CHF;4.1154;4.1986
# 5       funt szterling;GBP;5.2022;5.3072
# 6    jen (Japonia);JPY;0.034234;0.034926
# 7         korona czeska;CZK;0.176;0.1796
# 8        korona duńska;DKK;0.6011;0.6133
# 9      korona norweska;NOK;0.4354;0.4442
# 10     korona szwedzka;SEK;0.4403;0.4491
# 11           SDR (MFW);XDR;5.3836;5.4924

# %%
salaries = [
    ("Mark", 1000, 23),
    ("John", 1500, 25),
    ("Daniel", 2300, 38),
    ("Greg", 5000, 42),
    ("Filip", 7800, 53),
    ("Joseph", 7200, 67)
]


df = pd.DataFrame(salaries)
df
# Out:
#         0     1   2
# 0    Mark  1000  23
# 1    John  1500  25
# 2  Daniel  2300  38
# 3    Greg  5000  42
# 4   Filip  7800  53
# 5  Joseph  7200  67

# %%
df.head() # pokazuje pierwszych 5 rekordów
# Out:
#         0     1   2
# 0    Mark  1000  23
# 1    John  1500  25
# 2  Daniel  2300  38
# 3    Greg  5000  42
# 4   Filip  7800  53

# %%
df = pd.DataFrame(salaries, columns=["name", "salary", "age"])
df = df.set_index("name")
df
# Out:
#         salary  age
# name
# Mark      1000   23
# John      1500   25
# Daniel    2300   38
# Greg      5000   42
# Filip     7800   53
# Joseph    7200   67

# %%
df.describe()
# Out:
#             salary        age
# count     6.000000   6.000000
# mean   4133.333333  41.333333
# std    2956.800072  16.788885
# min    1000.000000  23.000000
# 25%    1700.000000  28.250000
# 50%    3650.000000  40.000000
# 75%    6650.000000  50.250000
# max    7800.000000  67.000000

# %%
salary_increased_series = df['salary'].apply(lambda salary: salary + 2000)
df['salary'] = salary_increased_series # co to wyrażenie daje w porównaniu do tego wyżej? Potrzebne do kolejnego przykładu z dodawaniem wektorów?

# %%
salary_increased_series
# Out:
# name
# Mark      3000
# John      3500
# Daniel    4300
# Greg      7000
# Filip     9800
# Joseph    9200
# Name: salary, dtype: int64

# %%
salary_raise = [2000, 2000, 2000, 2000, 2000, 2000]
df['salary'] + salary_raise # dodawanie dwóch wektorów
# Out:
# name
# Mark       5000
# John       5500
# Daniel     6300
# Greg       9000
# Filip     11800
# Joseph    11200
# Name: salary, dtype: int64

# %%
salaries = [
    ("Mark", 1000, 23),
    ("John", 1500, 25),
    ("Daniel", 2300, 38),
    ("Greg", 5000, 42)
]

df = pd.DataFrame(salaries, columns=['name', 'salary', 'age'])

df['Initials'] = ['M','J','D','G']

# %%
df
# Out:
#      name  salary  age Initials
# 0    Mark    1000   23        M
# 1    John    1500   25        J
# 2  Daniel    2300   38        D
# 3    Greg    5000   42        G

# %%
import matplotlib.pyplot as plt
plt.bar(df.index, df["salary"])
# Out:
# <BarContainer object of 4 artists>

# %%
df = df.set_index("name")
df['salary'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %%
df['age'].plot(kind='bar', title = 'Workers age', color = 'papayawhip')
# Out:
# <AxesSubplot:title={'center':'Workers age'}, xlabel='name'>
